# %% [markdown]
# # Optimizing Code: Common Books
# Here's the code your coworker wrote to find the common book ids in `books_published_last_two_years.txt` and `all_coding_books.txt` to obtain a list of recent coding books.

# %%
import time
import pandas as pd
import numpy as np

# %%
with open('books_published_last_two_years.txt') as f:
    recent_books = f.read().split('\n')
    
with open('all_coding_books.txt') as f:
    coding_books = f.read().split('\n')
    
print(f"size of books_published_last_two_years.txt: {len(recent_books)}")
print(f"size of all_coding_books.txt: {len(coding_books)}")
# Out:
# size of books_published_last_two_years.txt: 24159
# size of all_coding_books.txt: 32250

# %%
start = time.time()
recent_coding_books = []

for book in recent_books:
    if book in coding_books:
        recent_coding_books.append(book)

print(len(recent_coding_books))
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# 96
# Duration: 17.39790916442871 seconds

# %%
start = time.time()
recent_coding_books = []

for book in coding_books:
    if book in recent_books:
        recent_coding_books.append(book)

print(len(recent_coding_books))
print('Duration: {} seconds'.format(time.time() - start))
# Out:
# 96
# Duration: 17.427492380142212 seconds

# %% [markdown]
# ### Tip #1: Use vector operations over loops when possible
#
# Use numpy's `intersect1d` method to get the intersection of the `recent_books` and `coding_books` arrays.

# %%
# %%timeit -n100
recent_coding_books =  np.intersect1d(recent_books, coding_books) # TODO: compute intersection of lists
# Out:
# 26.6 ms ± 110 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n100
recent_coding_books =  np.intersect1d(coding_books, recent_books) # TODO: compute intersection of lists
# Out:
# 26.5 ms ± 84.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ### Tip #2: Know your data structures and which methods are faster
# Use the set's `intersection` method to get the common elements in `recent_books` and `coding_books`.

# %%
# %%timeit -n100
recent_coding_books =  list(set.intersection(set(recent_books), set(coding_books)))
# Out:
# 6.83 ms ± 56.4 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n100
recent_coding_books =  list(set.intersection(set(coding_books), set(recent_books)))
# Out:
# 6.84 ms ± 124 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n100
recent_coding_books =  [set.intersection(set(recent_books), set(coding_books))]
# Out:
# 6.85 ms ± 86.3 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -n100
recent_coding_books =  [set.intersection(set(coding_books), set(recent_books))]
# Out:
# 6.83 ms ± 169 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
